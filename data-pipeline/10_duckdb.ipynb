# %%
import pandas as pd

staff_detail_different_col_path = "staff_detail_different_col.csv"
staff_detail_path = "staff_detail.csv"
staff_samecol_path = "staff_samecol.csv"
staff_path = "staff.csv"

staff_detail_different_col_df = pd.read_csv(staff_detail_different_col_path)
staff_detail_df = pd.read_csv(staff_detail_path)
staff_samecol_df = pd.read_csv(staff_samecol_path)
staff_df = pd.read_csv(staff_path)

# %%
import duckdb

con = duckdb.connect()

# 讀 parquet 檔
df = con.execute("""
    SELECT *
    FROM 'staff_df'
""").fetchdf()

df
# Out:
#    ID   Name  DeptId  Age Gender  Salary
# 0   1   Mike       2   45      M   60000
# 1   2   Judy       2   30      F   48000
# 2   3  Allen       1   22      M   50000
# 3   4    Tom       2   47      M   47000
# 4   5   Jack       3   36      M   52000
# 5   6   Abby       2   24      F   45000
# 6   7  Trump       1   80      M   80000
# 7   8  Marry       3   29      F   87000

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'import pandas as pd\n\nstaff_detail_different_col_path = "staff_detail_different_col.csv"\nstaff_detail_path = "staff_detail.csv"\nstaff_samecol_path = "staff_samecol.csv"\nstaff_path = "staff.csv"\n\nstaff_detail_different_col_df = pd.read_csv(staff_detail_different_col_path)\nstaff_detail_df = pd.read_csv(staff_detail_path)\nstaff_samecol_df = pd.read_csv(staff_samecol_path)\nstaff_df = pd.read_csv(staff_path)',
#   'import duckdb\n\ncon = duckdb.connect()\n\n# 讀 parquet 檔\ndf = con.execute("""\n    SELECT *\n    FROM \'staff_df\'\n""").fetchdf()\n\ndf',
#   'globals()'],
#  '_oh': {2:    ID   Name  DeptId  Age Gender  Salary
#   0   1   Mike       2   45      M   60000
# ...

# %%
globals()["staff_df"]
# Out:
#    ID   Name  DeptId  Age Gender  Salary
# 0   1   Mike       2   45      M   60000
# 1   2   Judy       2   30      F   48000
# 2   3  Allen       1   22      M   50000
# 3   4    Tom       2   47      M   47000
# 4   5   Jack       3   36      M   52000
# 5   6   Abby       2   24      F   45000
# 6   7  Trump       1   80      M   80000
# 7   8  Marry       3   29      F   87000

# %%
locals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'import pandas as pd\n\nstaff_detail_different_col_path = "staff_detail_different_col.csv"\nstaff_detail_path = "staff_detail.csv"\nstaff_samecol_path = "staff_samecol.csv"\nstaff_path = "staff.csv"\n\nstaff_detail_different_col_df = pd.read_csv(staff_detail_different_col_path)\nstaff_detail_df = pd.read_csv(staff_detail_path)\nstaff_samecol_df = pd.read_csv(staff_samecol_path)\nstaff_df = pd.read_csv(staff_path)',
#   'import duckdb\n\ncon = duckdb.connect()\n\n# 讀 parquet 檔\ndf = con.execute("""\n    SELECT *\n    FROM \'staff_df\'\n""").fetchdf()\n\ndf',
#   'globals()',
#   'globals()["staff_df"]',
#   'locals()'],
#  '_oh': {2:    ID   Name  DeptId  Age Gender  Salary
# ...

# %%
import pandas as pd

file_path = "data_with_nan.csv"

df = pd.read_csv(file_path)

df
# Out:
#     col1  col2 col3
# 0  test1  13.0  NaN
# 1  test2  44.0  aaa
# 2  test3   NaN  NaN
# 3    NaN   NaN  NaN
# 4  test5   NaN  bbb
# 5    NaN   NaN  NaN

# %%
type(None)
# Out:
# NoneType

# %%
df["col2"][2]
# Out:
# np.float64(nan)

# %%
type(df["col2"][2])
# Out:
# numpy.float64

# %%
df["col2"].mean()
# Out:
# np.float64(28.5)

# %%
df["col2"].fillna(0)
# Out:
# 0    13.0
# 1    44.0
# 2     0.0
# 3     0.0
# 4     0.0
# 5     0.0
# Name: col2, dtype: float64

# %%
df["col2"].fillna(0).mean()
# Out:
# np.float64(9.5)

# %%
df["col3"].isna()
# Out:
# 0     True
# 1    False
# 2     True
# 3     True
# 4    False
# 5     True
# Name: col3, dtype: bool

# %%
df[
    df["col3"].isna()
]
# Out:
#     col1  col2 col3
# 0  test1  13.0  NaN
# 2  test3   NaN  NaN
# 3    NaN   NaN  NaN
# 5    NaN   NaN  NaN

# %%
df[
    ~(df["col3"].isna())
]
# Out:
#     col1  col2 col3
# 1  test2  44.0  aaa
# 4  test5   NaN  bbb

# %%
df[
    df["col3"].notna()
]
# Out:
#     col1  col2 col3
# 1  test2  44.0  aaa
# 4  test5   NaN  bbb

# %%
df
# Out:
#     col1  col2 col3
# 0  test1  13.0  NaN
# 1  test2  44.0  aaa
# 2  test3   NaN  NaN
# 3    NaN   NaN  NaN
# 4  test5   NaN  bbb
# 5    NaN   NaN  NaN

# %%
df.dropna()
# Out:
#     col1  col2 col3
# 1  test2  44.0  aaa

# %%
df.dropna(thresh=1)
# Out:
#     col1  col2 col3
# 0  test1  13.0  NaN
# 1  test2  44.0  aaa
# 2  test3   NaN  NaN
# 4  test5   NaN  bbb

# %%
df["col1"].ffill()
# Out:
# 0    test1
# 1    test2
# 2    test3
# 3    test3
# 4    test5
# 5    test5
# Name: col1, dtype: object

# %%
df["col1"].bfill()
# Out:
# 0    test1
# 1    test2
# 2    test3
# 3    test5
# 4    test5
# 5      NaN
# Name: col1, dtype: object

# %%
import pandas as pd

# %%
columns = ["Name", "Age", "Height"]
data = [
    ["Allen", 22, 175],  # the 0-th row of data
    ["Ted", 25, 180],  # the 1-st row of data
]

# %%
df = pd.DataFrame(
    columns=columns,
    data=data,
)

df
# Out:
#     Name  Age  Height
# 0  Allen   22     175
# 1    Ted   25     180

# %%
df.loc[2] = ["Jack", 28, 177]
df
# Out:
#     Name  Age  Height
# 0  Allen   22     175
# 1    Ted   25     180
# 2   Jack   28     177

# %%
df["Weight"] = [75, 80, 77]

df
# Out:
#     Name  Age  Height  Weight
# 0  Allen   22     175      75
# 1    Ted   25     180      80
# 2   Jack   28     177      77

# %%
df["Weight"] = 77

df
# Out:
#     Name  Age  Height  Weight
# 0  Allen   22     175      77
# 1    Ted   25     180      77
# 2   Jack   28     177      77

# %%
df.drop("Weight", axis=1)
# Out:
#     Name  Age  Height
# 0  Allen   22     175
# 1    Ted   25     180
# 2   Jack   28     177

# %%
df = df.drop("Weight", axis=1)
df
# Out:
#     Name  Age  Height
# 0  Allen   22     175
# 1    Ted   25     180
# 2   Jack   28     177

# %%
df.drop(2)
# Out:
#     Name  Age  Height
# 0  Allen   22     175
# 1    Ted   25     180

# %%
df
# Out:
#     Name  Age  Height
# 0  Allen   22     175
# 1    Ted   25     180
# 2   Jack   28     177

# %%
df = df.drop(2)
df
# Out:
#     Name  Age  Height
# 0  Allen   22     175
# 1    Ted   25     180

# %%
df.loc[0, "Age"]
# Out:
# np.int64(22)

# %%
df.loc[0, "Age"] = 25
df
# Out:
#     Name  Age  Height
# 0  Allen   25     175
# 1    Ted   25     180

# %%
df["Name"]
# Out:
# 0    Allen
# 1      Ted
# Name: Name, dtype: object

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df["Name"])
# Out:
# pandas.core.series.Series

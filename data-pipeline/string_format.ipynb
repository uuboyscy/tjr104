# %%
tmp_var = "hello world"
print(f"Print something: {tmp_var}")
print("Print something: {}".format(tmp_var))
print("Print something: {tmp_var}".format(tmp_var=tmp_var))
print("Print something: %s"%(tmp_var))
# Out:
# Print something: hello world
# Print something: hello world
# Print something: hello world
# Print something: hello world

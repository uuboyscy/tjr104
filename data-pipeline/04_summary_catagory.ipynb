# %%
import pandas as pd

file_path = "holding.parquet"

# %%
df = pd.read_parquet(file_path)
df
# Out:
#            portno   report_dt  security_rank      eff_dt  percent_tna  \
# 0         2998623  2020/11/30              1  2021/01/08         2.55
# 1         2998623  2020/11/30              2  2021/01/08         1.98
# 2         2998623  2020/11/30              3  2021/01/08         1.89
# 3         2998623  2020/11/30              4  2021/01/08         1.75
# 4         2998623  2020/11/30              5  2021/01/08         1.65
# ...           ...         ...            ...         ...          ...
# 13461477  3157350  2021/11/30            428  2021/12/21         0.11
# 13461478  3157350  2021/11/30            429  2021/12/21         0.11
# 13461479  3157350  2021/11/30            429  2021/12/21         0.11
# 13461480  3157350  2021/11/30            431  2021/12/21         0.10
# 13461481  3157350  2021/11/30            432  2021/12/21         0.08
#
#           nbr_shares    market_val  \
# 0          7078982.0  3.103426e+08
# 1          3087680.0  2.412404e+08
# ...

# %%
"""
select
    distinct(portno),
    count(distinct(portno))
from holding;
"""
df["portno"].unique()
# Out:
# array(['2998623', '2998638', '2998809', ..., '315724e', '3157332',
#        '3157350'], shape=(9453,), dtype=object)

# %%
df["security_name"].unique()
# Out:
# array(['GENERAL MOTORS CO', 'COGNIZANT TECHNOLOGY SOLS CORP',
#        'MORGAN STANLEY DEAN WITTER & CO', ...,
#        'AMERICREDIT AUTOMOBILE RECEIVABLES TRUST 212 A3 SEQ FIX .34% 18-DEC-2026',
#        'HYUNDAI AUTO RECEIVABLES TRUST 20C A4 FIX .49% 16-NOV-2026',
#        'COMM MORTGAGE TRUST 15CC26 D SEQ VAR 3.4782% 13-OCT-2048'],
#       shape=(342685,), dtype=object)

# %%
df["cusip"].unique()
# Out:
# array(['37045V10', '19244610', '61744644', ..., '98163EAE', '03066RAC',
#        '44891RAD'], shape=(257261,), dtype=object)

# %%
df.sort_values("security_name")
# Out:
#            portno   report_dt  security_rank      eff_dt  percent_tna  \
# 13167275  3082602  2021/11/30            754  2021/12/21         0.03
# 11793139  3062403  2021/10/31           3452  2021/11/19         0.00
# 10555794  3062403  2021/09/30           3398  2021/10/21         0.00
# 4933590   315154b  2021/03/31            572  2021/05/10         0.03
# 2764685   3062439  2021/02/28           3203  2021/03/23         0.00
# ...           ...         ...            ...         ...          ...
# 9757413   3152952  2021/08/31            490  2021/09/22         0.04
# 11288658  3082020  2021/09/30             46  2021/11/05         0.87
# 5769218   314472f  2021/04/30            972  2021/06/07         0.00
# 5215217   3094215  2021/04/30            179  2021/05/24         0.08
# 9322548   315180f  2021/08/31            184  2021/09/07         0.19
#
#           nbr_shares  market_val            security_name     cusip
# ...

# %%
df.groupby(["portno", "report_dt"])["percent_tna"].sum()
# Out:
# portno   report_dt
# 2998623  2020/11/30     99.79
#          2020/12/31     99.20
#          2021/03/31     99.96
#          2021/04/30     99.93
#          2021/06/30     99.78
#                         ...
# 3157308  2021/11/30    100.23
# 315732c  2021/11/30    100.12
# 3157332  2021/11/30     99.94
# 315733b  2021/11/30     99.73
# 3157350  2021/11/30     99.55
# Name: percent_tna, Length: 59339, dtype: float64

# %%
df.groupby(["portno", "eff_dt"])["percent_tna"].sum()
# Out:
# portno   eff_dt
# 2998623  2021/01/08     99.79
#          2021/02/05     99.20
#          2021/05/10     99.96
#          2021/06/07     99.93
#          2021/08/09     99.78
#                         ...
# 3157308  2021/12/07    100.23
# 315732c  2021/12/07    100.12
# 3157332  2021/12/21     99.94
# 315733b  2021/12/07     99.73
# 3157350  2021/12/21     99.55
# Name: percent_tna, Length: 59339, dtype: float64

# %%
df[
    df["portno"].isin(["2998623", "3157308", "315732c"])
]
# Out:
#            portno   report_dt  security_rank      eff_dt  percent_tna  \
# 0         2998623  2020/11/30              1  2021/01/08         2.55
# 1         2998623  2020/11/30              2  2021/01/08         1.98
# 2         2998623  2020/11/30              3  2021/01/08         1.89
# 3         2998623  2020/11/30              4  2021/01/08         1.75
# 4         2998623  2020/11/30              5  2021/01/08         1.65
# ...           ...         ...            ...         ...          ...
# 12944655  315732c  2021/11/30             28  2021/12/07         1.36
# 12944656  315732c  2021/11/30             29  2021/12/07         1.34
# 12944657  315732c  2021/11/30             30  2021/12/07         1.34
# 12944658  315732c  2021/11/30             31  2021/12/07         1.13
# 12944659  315732c  2021/11/30             33  2021/12/07       -26.63
#
#           nbr_shares    market_val                    security_name     cusip
# ...

# %%
df.groupby(["portno", "eff_dt"], as_index=False)["percent_tna"].sum()
# Out:
#         portno      eff_dt  percent_tna
# 0      2998623  2021/01/08        99.79
# 1      2998623  2021/02/05        99.20
# 2      2998623  2021/05/10        99.96
# 3      2998623  2021/06/07        99.93
# 4      2998623  2021/08/09        99.78
# ...        ...         ...          ...
# 59334  3157308  2021/12/07       100.23
# 59335  315732c  2021/12/07       100.12
# 59336  3157332  2021/12/21        99.94
# 59337  315733b  2021/12/07        99.73
# 59338  3157350  2021/12/21        99.55
#
# [59339 rows x 3 columns]

# %%
df.groupby(["portno", "eff_dt"], as_index=False).agg(
    percent_sum=("percent_tna", "sum"),
    percent_mean=("percent_tna", "mean"),
    percent_std=("percent_tna", "std"),
    percent_max=("percent_tna", "max"),
    percent_min=("percent_tna", "min"),
)
# Out:
#         portno      eff_dt  percent_sum  percent_mean  percent_std  \
# 0      2998623  2021/01/08        99.79      0.284302     0.436449
# 1      2998623  2021/02/05        99.20      0.284241     0.441951
# 2      2998623  2021/05/10        99.96      0.287241     0.488893
# 3      2998623  2021/06/07        99.93      0.288815     0.483873
# 4      2998623  2021/08/09        99.78      0.285086     0.484353
# ...        ...         ...          ...           ...          ...
# 59334  3157308  2021/12/07       100.23      0.415892     0.925469
# 59335  315732c  2021/12/07       100.12      3.128750     6.030084
# 59336  3157332  2021/12/21        99.94      0.197510     0.031781
# 59337  315733b  2021/12/07        99.73      6.233125     2.035465
# 59338  3157350  2021/12/21        99.55      0.232593     0.203393
#
#        percent_max  percent_min
# 0             2.55        -0.34
# 1             2.30        -0.33
# 2             3.14        -0.30
# ...

# %%
df.head()
# Out:
#     portno   report_dt  security_rank      eff_dt  percent_tna  nbr_shares  \
# 0  2998623  2020/11/30              1  2021/01/08         2.55   7078982.0
# 1  2998623  2020/11/30              2  2021/01/08         1.98   3087680.0
# 2  2998623  2020/11/30              3  2021/01/08         1.89   3714760.0
# 3  2998623  2020/11/30              4  2021/01/08         1.75   2815186.0
# 4  2998623  2020/11/30              5  2021/01/08         1.65   5248941.0
#
#      market_val                    security_name     cusip
# 0  3.103426e+08                GENERAL MOTORS CO  37045V10
# 1  2.412404e+08   COGNIZANT TECHNOLOGY SOLS CORP  19244610
# 2  2.296836e+08  MORGAN STANLEY DEAN WITTER & CO  61744644
# 3  2.132503e+08  PHILIP MORRIS INTERNATIONAL INC  71817210
# 4  2.011394e+08                      CORTEVA INC  22052L10

# %%
df.head(3)
# Out:
#     portno   report_dt  security_rank      eff_dt  percent_tna  nbr_shares  \
# 0  2998623  2020/11/30              1  2021/01/08         2.55   7078982.0
# 1  2998623  2020/11/30              2  2021/01/08         1.98   3087680.0
# 2  2998623  2020/11/30              3  2021/01/08         1.89   3714760.0
#
#      market_val                    security_name     cusip
# 0  3.103426e+08                GENERAL MOTORS CO  37045V10
# 1  2.412404e+08   COGNIZANT TECHNOLOGY SOLS CORP  19244610
# 2  2.296836e+08  MORGAN STANLEY DEAN WITTER & CO  61744644

# %%
df.tail()
# Out:
#            portno   report_dt  security_rank      eff_dt  percent_tna  \
# 13461477  3157350  2021/11/30            428  2021/12/21         0.11
# 13461478  3157350  2021/11/30            429  2021/12/21         0.11
# 13461479  3157350  2021/11/30            429  2021/12/21         0.11
# 13461480  3157350  2021/11/30            431  2021/12/21         0.10
# 13461481  3157350  2021/11/30            432  2021/12/21         0.08
#
#           nbr_shares  market_val  \
# 13461477     25000.0    22294.75
# 13461478     25000.0    21480.50
# 13461479     25000.0    21484.00
# 13461480     25000.0    19187.38
# 13461481     25000.0    14971.88
#
#                                           security_name     cusip
# 13461477     Bausch Health Companies Inc 5% 30-JAN-2028  071734AH
# 13461478  Bausch Health Companies Inc 5.25% 30-JAN-2030  071734AJ
# 13461479     Bausch Health Companies Inc 5% 15-FEB-2029  071734AM
# 13461480                        Endo DAC 6% 30-JUN-2028  29273DAC
# ...

# %%
df[5:10]
# Out:
#     portno   report_dt  security_rank      eff_dt  percent_tna  nbr_shares  \
# 5  2998623  2020/11/30              6  2021/01/08         1.64    866386.0
# 6  2998623  2020/11/30              7  2021/01/08         1.63   2194727.0
# 7  2998623  2020/11/30              8  2021/01/08         1.60   5045923.0
# 8  2998623  2020/11/30              9  2021/01/08         1.59   1403360.0
# 9  2998623  2020/11/30             10  2021/01/08         1.54   3065766.0
#
#      market_val                     security_name     cusip
# 5  1.997713e+08           GOLDMAN SACHS GROUP INC  38141G10
# 6  1.976352e+08                        C S X CORP  12640810
# 7  1.939653e+08  AMERICAN INTERNATIONAL GROUP INC  02687478
# 8  1.937619e+08  P N C FINANCIAL SERVICES GRP INC  69347510
# 9  1.874409e+08                 C B R E GROUP INC  12504L10

# %%
df.loc[5:10, "portno":"security_rank"]
# Out:
#      portno   report_dt  security_rank
# 5   2998623  2020/11/30              6
# 6   2998623  2020/11/30              7
# 7   2998623  2020/11/30              8
# 8   2998623  2020/11/30              9
# 9   2998623  2020/11/30             10
# 10  2998623  2020/11/30             11

# %%
df.loc[5:10, ["portno", "report_dt", "security_rank"]]
# Out:
#      portno   report_dt  security_rank
# 5   2998623  2020/11/30              6
# 6   2998623  2020/11/30              7
# 7   2998623  2020/11/30              8
# 8   2998623  2020/11/30              9
# 9   2998623  2020/11/30             10
# 10  2998623  2020/11/30             11

# %%
df.loc[[5, 6, 7, 8, 9, 10], ["portno", "report_dt", "security_rank"]]
# Out:
#      portno   report_dt  security_rank
# 5   2998623  2020/11/30              6
# 6   2998623  2020/11/30              7
# 7   2998623  2020/11/30              8
# 8   2998623  2020/11/30              9
# 9   2998623  2020/11/30             10
# 10  2998623  2020/11/30             11

# %%
df.iloc[[5, 6, 7, 8, 9, 10], [1, 3, 5]]
# Out:
#      report_dt      eff_dt   nbr_shares
# 5   2020/11/30  2021/01/08     866386.0
# 6   2020/11/30  2021/01/08    2194727.0
# 7   2020/11/30  2021/01/08    5045923.0
# 8   2020/11/30  2021/01/08    1403360.0
# 9   2020/11/30  2021/01/08    3065766.0
# 10  2020/11/30  2021/01/08  186854700.0

# %%
df.columns
# Out:
# Index(['portno', 'report_dt', 'security_rank', 'eff_dt', 'percent_tna',
#        'nbr_shares', 'market_val', 'security_name', 'cusip'],
#       dtype='object')

# %%
df.dtypes
# Out:
# portno            object
# report_dt         object
# security_rank      int64
# eff_dt            object
# percent_tna      float64
# nbr_shares       float64
# market_val       float64
# security_name     object
# cusip             object
# dtype: object

# %%
df.describe()
# Out:
#        security_rank   percent_tna    nbr_shares    market_val
# count   1.346148e+07  1.346148e+07  1.346148e+07  1.346148e+07
# mean    5.865976e+02  4.404682e-01  2.438436e+07  1.137428e+07
# std     8.539445e+02  2.125681e+00  6.523191e+09  1.651424e+08
# min     1.000000e+00 -2.489000e+02 -1.027540e+12 -6.520285e+09
# 25%     8.200000e+01  2.000000e-02  5.744000e+03  1.153754e+05
# 50%     2.750000e+02  8.000000e-02  5.249300e+04  6.464532e+05
# 75%     7.270000e+02  3.100000e-01  4.488590e+05  3.176073e+06
# max     8.716000e+03  3.028200e+02  6.667220e+12  7.118158e+10
